# %%
import pandas as pd

# %%
import os

# %%
data_dir = 'Data'

# %%
csv_file = "Participant 1_Aleksashina_Analysis 1_video_20190607_114857_detailed.csv"
csv_path = os.path.join(data_dir, csv_file)

# %%
df = pd.read_csv(csv_path, sep='\t', skiprows = lambda i: i in range(8))

# %%
df_first = df.columns[0]
df.columns = df.columns[1:].insert(-2, 'UNKNOWN')
df.insert(0, df_first, df.index)
df
# Out:
#                 Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:00.000  00:00:00.000  0.973121  0.019527  0.000404  0.043879   0.004099
# 00:00:00.100  00:00:00.100  0.974289  0.020129  0.000382  0.042413   0.004014
# 00:00:00.200  00:00:00.200  0.975457  0.020731  0.000361  0.040947   0.003930
# 00:00:00.300  00:00:00.300  0.975028  0.020480  0.000345  0.042622   0.003916
# 00:00:00.400  00:00:00.400  0.974542  0.020394  0.000326  0.044417   0.003831
# ...                    ...       ...       ...       ...       ...        ...
# 00:01:50.900  00:01:50.900  0.969587  0.016939  0.000846  0.051552   0.004851
# 00:01:51.000  00:01:51.000  0.969071  0.017130  0.000856  0.052158   0.004848
# 00:01:51.100  00:01:51.100  0.968842  0.017460  0.000885  0.052096   0.004807
# 00:01:51.200  00:01:51.200  0.968608  0.018322  0.000899  0.052130   0.004756
# 00:01:51.300  00:01:51.300  0.968453  0.019037  0.000889  0.052191   0.004726
#
# ...

# %%
#Add Kerov

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 2_video_20190605_104736_detailed.csv"
csv_path = os.path.join(data_dir, csv_file)

# %%
df_2 = pd.read_csv(csv_path, sep='\t', skiprows = lambda i: i in range(8))

# %%
df_2
# Out:
#               Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:00.000    0.988882  0.003717  0.001937  0.000500  0.019612   0.000040
# 00:00:00.030    0.988699  0.003657  0.001927  0.000496  0.019872   0.000042
# 00:00:00.060    0.988516  0.003598  0.001917  0.000492  0.020131   0.000043
# 00:00:00.090    0.988333  0.003538  0.001907  0.000489  0.020391   0.000044
# 00:00:00.121    0.988150  0.003479  0.001897  0.000485  0.020650   0.000045
# ...                  ...       ...       ...       ...       ...        ...
# 00:00:11.848    0.870583  0.124975  0.029658  0.000086  0.012401   0.000102
# 00:00:11.878    0.878502  0.115823  0.032183  0.000088  0.012449   0.000102
# 00:00:11.909    0.885733  0.107336  0.034626  0.000089  0.012490   0.000102
# 00:00:11.939    0.892027  0.099729  0.036990  0.000091  0.012511   0.000102
# 00:00:11.969    0.898321  0.092121  0.039354  0.000092  0.012532   0.000102
#
# ...

# %%
df_2.index
# Out:
# Index(['00:00:00.000', '00:00:00.030', '00:00:00.060', '00:00:00.090',
#        '00:00:00.121', '00:00:00.151', '00:00:00.181', '00:00:00.212',
#        '00:00:00.242', '00:00:00.272',
#        ...
#        '00:00:11.696', '00:00:11.727', '00:00:11.757', '00:00:11.787',
#        '00:00:11.818', '00:00:11.848', '00:00:11.878', '00:00:11.909',
#        '00:00:11.939', '00:00:11.969'],
#       dtype='object', length=396)

# %%
[index + '_Керов Андрей_2' for index in df_2.index]
# Out:
# ['00:00:00.000_Керов Андрей_2',
#  '00:00:00.030_Керов Андрей_2',
#  '00:00:00.060_Керов Андрей_2',
#  '00:00:00.090_Керов Андрей_2',
#  '00:00:00.121_Керов Андрей_2',
#  '00:00:00.151_Керов Андрей_2',
#  '00:00:00.181_Керов Андрей_2',
#  '00:00:00.212_Керов Андрей_2',
#  '00:00:00.242_Керов Андрей_2',
#  '00:00:00.272_Керов Андрей_2',
#  '00:00:00.303_Керов Андрей_2',
#  '00:00:00.333_Керов Андрей_2',
#  '00:00:00.363_Керов Андрей_2',
#  '00:00:00.393_Керов Андрей_2',
#  '00:00:00.424_Керов Андрей_2',
#  '00:00:00.454_Керов Андрей_2',
#  '00:00:00.484_Керов Андрей_2',
#  '00:00:00.515_Керов Андрей_2',
#  '00:00:00.545_Керов Андрей_2',
#  '00:00:00.575_Керов Андрей_2',
#  '00:00:00.606_Керов Андрей_2',
#  '00:00:00.636_Керов Андрей_2',
#  '00:00:00.666_Керов Андрей_2',
#  '00:00:00.696_Керов Андрей_2',
#  '00:00:00.727_Керов Андрей_2',
#  '00:00:00.757_Керов Андрей_2',
#  '00:00:00.787_Керов Андрей_2',
#  '00:00:00.818_Керов Андрей_2',
#  '00:00:00.848_Керов Андрей_2',
# ...

# %%
def create_correct_df(df, add_to_index):
    df_first = df.columns[0]
    df.columns = df.columns[1:].insert(-2, 'UNKNOWN')
    df.insert(0, df_first, df.index)
    df.index = [index + add_to_index for index in df.index]
    return df

# %%
df_2 = create_correct_df(df_2, '_Керов Андрей_2')
df_2
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000_Керов Андрей_2  00:00:00.000  0.988882  0.003717  0.001937
# 00:00:00.030_Керов Андрей_2  00:00:00.030  0.988699  0.003657  0.001927
# 00:00:00.060_Керов Андрей_2  00:00:00.060  0.988516  0.003598  0.001917
# 00:00:00.090_Керов Андрей_2  00:00:00.090  0.988333  0.003538  0.001907
# 00:00:00.121_Керов Андрей_2  00:00:00.121  0.988150  0.003479  0.001897
# ...                                   ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_2  00:00:11.848  0.870583  0.124975  0.029658
# 00:00:11.878_Керов Андрей_2  00:00:11.878  0.878502  0.115823  0.032183
# 00:00:11.909_Керов Андрей_2  00:00:11.909  0.885733  0.107336  0.034626
# 00:00:11.939_Керов Андрей_2  00:00:11.939  0.892027  0.099729  0.036990
# 00:00:11.969_Керов Андрей_2  00:00:11.969  0.898321  0.092121  0.039354
#
#                                 Angry  Surprised    Scared  Disgusted  \
# ...

# %%
df = pd.concat([df, df_2], axis=0)
df
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                 00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                 00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                 00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                 00:00:00.300  0.975028  0.020480  0.000345
# 00:00:00.400                 00:00:00.400  0.974542  0.020394  0.000326
# ...                                   ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_2  00:00:11.848  0.870583  0.124975  0.029658
# 00:00:11.878_Керов Андрей_2  00:00:11.878  0.878502  0.115823  0.032183
# 00:00:11.909_Керов Андрей_2  00:00:11.909  0.885733  0.107336  0.034626
# 00:00:11.939_Керов Андрей_2  00:00:11.939  0.892027  0.099729  0.036990
# 00:00:11.969_Керов Андрей_2  00:00:11.969  0.898321  0.092121  0.039354
#
#                                 Angry  Surprised    Scared  Disgusted  \
# ...

# %%
df['00:00:00.000':'00:00:00.400']
# Out:
#                 Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:00.000  00:00:00.000  0.973121  0.019527  0.000404  0.043879   0.004099
# 00:00:00.100  00:00:00.100  0.974289  0.020129  0.000382  0.042413   0.004014
# 00:00:00.200  00:00:00.200  0.975457  0.020731  0.000361  0.040947   0.003930
# 00:00:00.300  00:00:00.300  0.975028  0.020480  0.000345  0.042622   0.003916
# 00:00:00.400  00:00:00.400  0.974542  0.020394  0.000326  0.044417   0.003831
#
#                 Scared  Disgusted   Valence   Arousal  ...  \
# 00:00:00.000  0.000322   0.001946 -0.024352  0.255187  ...
# 00:00:00.100  0.000298   0.001820 -0.022284  0.260074  ...
# 00:00:00.200  0.000273   0.001693 -0.020216  0.264960  ...
# 00:00:00.300  0.000256   0.001549 -0.022143  0.269347  ...
# 00:00:00.400  0.000235   0.001438 -0.024022  0.273202  ...
#
#              Action Unit 12 - Right - Lip Corner Puller  \
# 00:00:00.000                                        0.0
# ...

# %%
df['00:00:00.000_Керов Андрей_2':'00:00:00.121_Керов Андрей_2']
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000_Керов Андрей_2  00:00:00.000  0.988882  0.003717  0.001937
# 00:00:00.030_Керов Андрей_2  00:00:00.030  0.988699  0.003657  0.001927
# 00:00:00.060_Керов Андрей_2  00:00:00.060  0.988516  0.003598  0.001917
# 00:00:00.090_Керов Андрей_2  00:00:00.090  0.988333  0.003538  0.001907
# 00:00:00.121_Керов Андрей_2  00:00:00.121  0.988150  0.003479  0.001897
#
#                                 Angry  Surprised    Scared  Disgusted  \
# 00:00:00.000_Керов Андрей_2  0.000500   0.019612  0.000040   0.000052
# 00:00:00.030_Керов Андрей_2  0.000496   0.019872  0.000042   0.000051
# 00:00:00.060_Керов Андрей_2  0.000492   0.020131  0.000043   0.000050
# 00:00:00.090_Керов Андрей_2  0.000489   0.020391  0.000044   0.000050
# 00:00:00.121_Керов Андрей_2  0.000485   0.020650  0.000045   0.000049
#
#                               Valence  Arousal  ...  \
# 00:00:00.000_Керов Андрей_2  0.001780   0.2475  ...
# ...

# %%
#Next Kerov

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 3_video_20190605_104736_detailed.csv"
csv_path = os.path.join(data_dir, csv_file)
df_2 = pd.read_csv(csv_path, sep='\t', skiprows = lambda i: i in range(8))
df_2 = create_correct_df(df_2, '_Керов Андрей_3')
df = pd.concat([df, df_2], axis=0)
df
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                 00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                 00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                 00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                 00:00:00.300  0.975028  0.020480  0.000345
# 00:00:00.400                 00:00:00.400  0.974542  0.020394  0.000326
# ...                                   ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_3  00:00:11.848  0.951203  0.000446  0.025843
# 00:00:11.878_Керов Андрей_3  00:00:11.878  0.951466  0.000453  0.025639
# 00:00:11.909_Керов Андрей_3  00:00:11.909  0.951872  0.000457  0.025467
# 00:00:11.939_Керов Андрей_3  00:00:11.939  0.952342  0.000461  0.025314
# 00:00:11.969_Керов Андрей_3  00:00:11.969  0.952872  0.000461  0.025237
#
#                                 Angry  Surprised    Scared  Disgusted  \
# ...

# %%
df['00:00:00.000_Керов Андрей_3':'00:00:00.121_Керов Андрей_3']
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000_Керов Андрей_3  00:00:00.000  0.987859  0.003336  0.008397
# 00:00:00.030_Керов Андрей_3  00:00:00.030  0.987882  0.003385  0.008362
# 00:00:00.060_Керов Андрей_3  00:00:00.060  0.987905  0.003434  0.008327
# 00:00:00.090_Керов Андрей_3  00:00:00.090  0.987929  0.003483  0.008292
# 00:00:00.121_Керов Андрей_3  00:00:00.121  0.988026  0.003506  0.008184
#
#                                 Angry  Surprised    Scared  Disgusted  \
# 00:00:00.000_Керов Андрей_3  0.001824   0.007601  0.000069   0.000141
# 00:00:00.030_Керов Андрей_3  0.001783   0.007645  0.000081   0.000139
# 00:00:00.060_Керов Андрей_3  0.001741   0.007689  0.000092   0.000136
# 00:00:00.090_Керов Андрей_3  0.001700   0.007733  0.000103   0.000134
# 00:00:00.121_Керов Андрей_3  0.001645   0.007784  0.000113   0.000130
#
#                               Valence  Arousal  ...  \
# 00:00:00.000_Керов Андрей_3 -0.005061   0.2475  ...
# ...

# %%
def concat_next_csv(df, data_dir, csv_file, add_to_index):
    csv_path = os.path.join(data_dir, csv_file)
    df_2 = pd.read_csv(csv_path, sep='\t', skiprows = lambda i: i in range(8))
    df_2 = create_correct_df(df_2, add_to_index)
    df = pd.concat([df, df_2], axis=0)
    return df

# %%
#FIT_FAILED!!! FIND_FAILED

csv_file = "Participant 1_Керов Андрей_Analysis 4_video_20190605_104737_detailed.csv"
add_to_index = '_Керов Андрей_4'
df = concat_next_csv(df, data_dir, csv_file, add_to_index)
df
# Out:
#                                Video Time      Neutral        Happy  \
# 00:00:00.000                 00:00:00.000     0.973121     0.019527
# 00:00:00.100                 00:00:00.100     0.974289     0.020129
# 00:00:00.200                 00:00:00.200     0.975457     0.020731
# 00:00:00.300                 00:00:00.300     0.975028      0.02048
# 00:00:00.400                 00:00:00.400     0.974542     0.020394
# ...                                   ...          ...          ...
# 00:00:11.848_Керов Андрей_4  00:00:11.848   FIT_FAILED   FIT_FAILED
# 00:00:11.878_Керов Андрей_4  00:00:11.878  FIND_FAILED  FIND_FAILED
# 00:00:11.909_Керов Андрей_4  00:00:11.909  0.521530800  0.073758440
# 00:00:11.939_Керов Андрей_4  00:00:11.939  0.526530100  0.073794510
# 00:00:11.969_Керов Андрей_4  00:00:11.969  0.531529500  0.073830590
#
#                                      Sad        Angry    Surprised  \
# 00:00:00.000                    0.000404     0.043879     0.004099
# ...

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 5_video_20190605_104737_detailed.csv"
add_to_index = '_Керов Андрей_5'
df = concat_next_csv(df, csv_file, add_to_index)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7873b0190649> in <module>
#       1 csv_file = "Participant 1_Керов Андрей_Analysis 5_video_20190605_104737_detailed.csv"
#       2 add_to_index = '_Керов Андрей_5'
# ----> 3 df = concat_next_csv(df, csv_file, add_to_index)
#       4 df
#
# TypeError: concat_next_csv() missing 1 required positional argument: 'add_to_index'

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 6_video_20190605_105549_detailed.csv"
add_to_index = '_Керов Андрей_6'
df = concat_next_csv(df, csv_file, add_to_index)
df
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                 00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                 00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                 00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                 00:00:00.300  0.975028   0.02048  0.000345
# 00:00:00.400                 00:00:00.400  0.974542  0.020394  0.000326
# ...                                   ...       ...       ...       ...
# 00:00:10.848_Керов Андрей_6  00:00:10.848  0.942625  0.000743  0.009426
# 00:00:10.878_Керов Андрей_6  00:00:10.878  0.944008  0.000893  0.009254
# 00:00:10.909_Керов Андрей_6  00:00:10.909  0.945237   0.00107  0.009095
# 00:00:10.939_Керов Андрей_6  00:00:10.939  0.945607  0.001341  0.008917
# 00:00:10.969_Керов Андрей_6  00:00:10.969  0.944558  0.001668  0.008749
#
#                                 Angry Surprised    Scared Disgusted   Valence  \
# ...

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 7_video_20190605_105550_detailed.csv"
add_to_index = '_Керов Андрей_7'
df = concat_next_csv(df, csv_file, add_to_index)
df
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                 00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                 00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                 00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                 00:00:00.300  0.975028   0.02048  0.000345
# 00:00:00.400                 00:00:00.400  0.974542  0.020394  0.000326
# ...                                   ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_7  00:00:11.848  0.690559  0.064714   0.10055
# 00:00:11.878_Керов Андрей_7  00:00:11.878  0.681011  0.062666  0.103674
# 00:00:11.909_Керов Андрей_7  00:00:11.909  0.671103  0.061273  0.106858
# 00:00:11.939_Керов Андрей_7  00:00:11.939  0.661001  0.060528  0.110367
# 00:00:11.969_Керов Андрей_7  00:00:11.969  0.650824  0.061005  0.113658
#
#                                 Angry Surprised    Scared Disgusted   Valence  \
# ...

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 8_video_20190605_105550_detailed.csv"
add_to_index = '_Керов Андрей_8'
df = concat_next_csv(df, csv_file, add_to_index)
df
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                 00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                 00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                 00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                 00:00:00.300  0.975028   0.02048  0.000345
# 00:00:00.400                 00:00:00.400  0.974542  0.020394  0.000326
# ...                                   ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_8  00:00:11.848  0.897728  0.148686  0.002992
# 00:00:11.878_Керов Андрей_8  00:00:11.878  0.899138  0.147494  0.002959
# 00:00:11.909_Керов Андрей_8  00:00:11.909  0.900226  0.146945  0.002921
# 00:00:11.939_Керов Андрей_8  00:00:11.939  0.900852  0.147182  0.002884
# 00:00:11.969_Керов Андрей_8  00:00:11.969  0.901039  0.148163  0.002879
#
#                                 Angry Surprised    Scared Disgusted   Valence  \
# ...

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 9_video_20190605_105551_detailed.csv"
add_to_index = '_Керов Андрей_9'
df = concat_next_csv(df, csv_file, add_to_index)
df
# Out:
#                                Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                 00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                 00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                 00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                 00:00:00.300  0.975028   0.02048  0.000345
# 00:00:00.400                 00:00:00.400  0.974542  0.020394  0.000326
# ...                                   ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_9  00:00:11.848   0.92348   0.11122  0.001324
# 00:00:11.878_Керов Андрей_9  00:00:11.878  0.928631   0.10371   0.00135
# 00:00:11.909_Керов Андрей_9  00:00:11.909  0.933367  0.096776  0.001376
# 00:00:11.939_Керов Андрей_9  00:00:11.939  0.938102  0.089843  0.001401
# 00:00:11.969_Керов Андрей_9  00:00:11.969  0.942288   0.08368  0.001446
#
#                                 Angry Surprised    Scared Disgusted   Valence  \
# ...

# %%
csv_file = "Participant 1_Керов Андрей_Analysis 10_video_20190605_105552_detailed.csv"
add_to_index = '_Керов Андрей_10'
df = concat_next_csv(df, csv_file, add_to_index)
df
# Out:
#                                 Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                  00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                  00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                  00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                  00:00:00.300  0.975028   0.02048  0.000345
# 00:00:00.400                  00:00:00.400  0.974542  0.020394  0.000326
# ...                                    ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_10  00:00:11.848  0.987148  0.001913  0.007843
# 00:00:11.878_Керов Андрей_10  00:00:11.878  0.987301  0.001948  0.007717
# 00:00:11.909_Керов Андрей_10  00:00:11.909  0.987427  0.001982  0.007622
# 00:00:11.939_Керов Андрей_10  00:00:11.939  0.987552  0.002006  0.007548
# 00:00:11.969_Керов Андрей_10  00:00:11.969  0.987646  0.002009   0.00753
#
#                                  Angry Surprised    Scared Disgusted  \
# ...

# %%
df = df[ # Without FIT_FAILED and FIND_FAILED
    (df['Neutral'] != 'FIT_FAILED') & 
    (df['Neutral'] != 'FIND_FAILED')
]
df
# Out:
#                                 Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                  00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                  00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                  00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                  00:00:00.300  0.975028   0.02048  0.000345
# 00:00:00.400                  00:00:00.400  0.974542  0.020394  0.000326
# ...                                    ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_10  00:00:11.848  0.987148  0.001913  0.007843
# 00:00:11.878_Керов Андрей_10  00:00:11.878  0.987301  0.001948  0.007717
# 00:00:11.909_Керов Андрей_10  00:00:11.909  0.987427  0.001982  0.007622
# 00:00:11.939_Керов Андрей_10  00:00:11.939  0.987552  0.002006  0.007548
# 00:00:11.969_Керов Андрей_10  00:00:11.969  0.987646  0.002009   0.00753
#
#                                  Angry Surprised    Scared Disgusted  \
# ...

# %%
df.insert(0, 'Index_', df.index)
df
# Out:
#                                                     Index_    Video Time  \
# 00:00:00.000                                  00:00:00.000  00:00:00.000
# 00:00:00.100                                  00:00:00.100  00:00:00.100
# 00:00:00.200                                  00:00:00.200  00:00:00.200
# 00:00:00.300                                  00:00:00.300  00:00:00.300
# 00:00:00.400                                  00:00:00.400  00:00:00.400
# ...                                                    ...           ...
# 00:00:11.848_Керов Андрей_10  00:00:11.848_Керов Андрей_10  00:00:11.848
# 00:00:11.878_Керов Андрей_10  00:00:11.878_Керов Андрей_10  00:00:11.878
# 00:00:11.909_Керов Андрей_10  00:00:11.909_Керов Андрей_10  00:00:11.909
# 00:00:11.939_Керов Андрей_10  00:00:11.939_Керов Андрей_10  00:00:11.939
# 00:00:11.969_Керов Андрей_10  00:00:11.969_Керов Андрей_10  00:00:11.969
#
#                                Neutral     Happy       Sad     Angry  \
# ...

# %%
# df = df.drop('Index', 1) # Удаление столбца
# df
# Out:
# <ipython-input-226-108947f8fc45>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Index', 1)
#                                                     Index_    Video Time  \
# 00:00:00.000                                  00:00:00.000  00:00:00.000
# 00:00:00.100                                  00:00:00.100  00:00:00.100
# 00:00:00.200                                  00:00:00.200  00:00:00.200
# 00:00:00.300                                  00:00:00.300  00:00:00.300
# 00:00:00.400                                  00:00:00.400  00:00:00.400
# ...                                                    ...           ...
# 00:00:11.848_Керов Андрей_10  00:00:11.848_Керов Андрей_10  00:00:11.848
# 00:00:11.878_Керов Андрей_10  00:00:11.878_Керов Андрей_10  00:00:11.878
# 00:00:11.909_Керов Андрей_10  00:00:11.909_Керов Андрей_10  00:00:11.909
# ...

# %%
# df = df.drop('Index_', 1) # Удаление столбца
# df
# Out:
# <ipython-input-227-47a366f01af7>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Index_', 1)
#                                 Video Time   Neutral     Happy       Sad  \
# 00:00:00.000                  00:00:00.000  0.973121  0.019527  0.000404
# 00:00:00.100                  00:00:00.100  0.974289  0.020129  0.000382
# 00:00:00.200                  00:00:00.200  0.975457  0.020731  0.000361
# 00:00:00.300                  00:00:00.300  0.975028   0.02048  0.000345
# 00:00:00.400                  00:00:00.400  0.974542  0.020394  0.000326
# ...                                    ...       ...       ...       ...
# 00:00:11.848_Керов Андрей_10  00:00:11.848  0.987148  0.001913  0.007843
# 00:00:11.878_Керов Андрей_10  00:00:11.878  0.987301  0.001948  0.007717
# 00:00:11.909_Керов Андрей_10  00:00:11.909  0.987427  0.001982  0.007622
# ...

# %%
# Запись в бд

# %%
import sqlite3

# %%
name_db = 'Aleksashina_Керов_Андрей'
db_file = f"{name_db}.db"
db_path = os.path.join(data_dir, db_file)

# %%
db_path
# Out:
# 'Data/Aleksashina_Керов_Андрей.db'

# %%
connection = sqlite3.connect(db_path)

# %%
df.columns
# Out:
# Index(['Index_', 'Video Time', 'Neutral', 'Happy', 'Sad', 'Angry', 'Surprised',
#        'Scared', 'Disgusted', 'Valence', 'Arousal', 'Gender', 'Age', 'Beard',
#        'Moustache', 'Glasses', 'Ethnicity', 'Y - Head Orientation',
#        'X - Head Orientation', 'Z - Head Orientation', 'Landmarks',
#        '3d Landmarks', 'Quality', 'Mouth', 'Left Eye', 'Right Eye',
#        'Left Eyebrow', 'Right Eyebrow', 'Identity',
#        'Action Unit 01 - Inner Brow Raiser',
#        'Action Unit 02 - Outer Brow Raiser', 'Action Unit 04 - Brow Lowerer',
#        'Action Unit 05 - Upper Lid Raiser', 'Action Unit 06 - Cheek Raiser',
#        'Action Unit 07 - Lid Tightener', 'Action Unit 09 - Nose Wrinkler',
#        'Action Unit 10 - Upper Lip Raiser',
#        'Action Unit 12 - Lip Corner Puller', 'Action Unit 14 - Dimpler',
#        'Action Unit 15 - Lip Corner Depressor', 'Action Unit 17 - Chin Raiser',
#        'Action Unit 18 - Lip Pucker', 'Action Unit 20 - Lip Stretcher',
# ...

# %%
df.columns[-10].replace('-', '_')
# Out:
# 'Action Unit 12 _ Right _ Lip Corner Puller'

# %%
df_columns = [field.replace('-', '_') for field in df.columns]
df_columns = [field.replace(' ', '_') for field in df_columns]
i = df_columns.index('3d_Landmarks')
df_columns[i] = 'three_d_Landmarks'
fields = ',\n'.join([f'\t{field} TEXT' for field in df_columns])
print(fields)
# Out:
# 	Index_ TEXT,
# 	Video_Time TEXT,
# 	Neutral TEXT,
# 	Happy TEXT,
# 	Sad TEXT,
# 	Angry TEXT,
# 	Surprised TEXT,
# 	Scared TEXT,
# 	Disgusted TEXT,
# 	Valence TEXT,
# 	Arousal TEXT,
# 	Gender TEXT,
# 	Age TEXT,
# 	Beard TEXT,
# 	Moustache TEXT,
# 	Glasses TEXT,
# 	Ethnicity TEXT,
# 	Y___Head_Orientation TEXT,
# 	X___Head_Orientation TEXT,
# 	Z___Head_Orientation TEXT,
# 	Landmarks TEXT,
# 	three_d_Landmarks TEXT,
# 	Quality TEXT,
# 	Mouth TEXT,
# 	Left_Eye TEXT,
# 	Right_Eye TEXT,
# 	Left_Eyebrow TEXT,
# 	Right_Eyebrow TEXT,
# 	Identity TEXT,
# 	Action_Unit_01___Inner_Brow_Raiser TEXT,
# 	Action_Unit_02___Outer_Brow_Raiser TEXT,
# 	Action_Unit_04___Brow_Lowerer TEXT,
# 	Action_Unit_05___Upper_Lid_Raiser TEXT,
# 	Action_Unit_06___Cheek_Raiser TEXT,
# 	Action_Unit_07___Lid_Tightener TEXT,
# 	Action_Unit_09___Nose_Wrinkler TEXT,
# 	Action_Unit_10___Upper_Lip_Raiser TEXT,
# 	Action_Unit_12___Lip_Corner_Puller TEXT,
# 	Action_Unit_14___Dimpler TEXT,
# ...

# %%
create_costs_table_query = f"""
create table {name_db} (
{fields}
)
"""
connection.execute(create_costs_table_query)
connection.commit()

# %%
values = ', '.join(['?' for _ in range(len(df.columns))])
values
# Out:
# '?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?'

# %%
len(df.columns)
# Out:
# 76

# %%
list(df.iterrows())
# Out:
# [('00:00:00.000',
#   Index_                 00:00:00.000
#   Video Time             00:00:00.000
#   Neutral                    0.973121
#   Happy                      0.019527
#   Sad                        0.000404
#                            ...
#   Stimulus                No Stimulus
#   Event Marker        No Event Marker
#   UNKNOWN                     UNKNOWN
#   Participant Name        Aleksashina
#   Analysis Index           Analysis 1
#   Name: 00:00:00.000, Length: 76, dtype: object),
#  ('00:00:00.100',
#   Index_                 00:00:00.100
#   Video Time             00:00:00.100
#   Neutral                    0.974289
#   Happy                      0.020129
#   Sad                        0.000382
#                            ...
#   Stimulus                No Stimulus
#   Event Marker        No Event Marker
#   UNKNOWN                     UNKNOWN
#   Participant Name        Aleksashina
#   Analysis Index           Analysis 1
# ...

# %%
tuple(list(df.iterrows())[0][1])
# Out:
# ('00:00:00.000',
#  '00:00:00.000',
#  0.9731213,
#  0.01952708,
#  0.000403907,
#  0.04387918,
#  0.004098584,
#  0.000322345,
#  0.001946207,
#  -0.0243521,
#  0.2551869,
#  'Female',
#  '20 - 30',
#  'None',
#  'None',
#  'No',
#  'Caucasian',
#  8.880192,
#  -0.4511606,
#  -0.1685847,
# ...

# %%
for row in df.iterrows():
#         print(type(row[1]))
        connection.execute(f"INSERT INTO {name_db} VALUES({values})", tuple(row[1]))
connection.commit()

# %%
def save_to_db(db_path, df):
    connection = sqlite3.connect(db_path)
    df_columns = [field.replace('-', '_') for field in df.columns]
    df_columns = [field.replace(' ', '_') for field in df_columns]
    i = df_columns.index('3d_Landmarks')
    df_columns[i] = 'three_d_Landmarks'
    fields = ',\n'.join([f'\t{field} TEXT' for field in df_columns])
    create_costs_table_query = f"""
create table {name_db} (
{fields}
)
"""
    connection.execute(create_costs_table_query)
    connection.commit()
    for row in df.iterrows():
        connection.execute(f"INSERT OR IGNORE INTO {name_db} VALUES({values})", tuple(row[1]))
    connection.commit()
    return connection

# %%
db_path
# Out:
# 'Data/Aleksashina_Керов_Андрей.db'

# %%
df
# Out:
#                                                     Index_    Video Time  \
# 00:00:00.000                                  00:00:00.000  00:00:00.000
# 00:00:00.100                                  00:00:00.100  00:00:00.100
# 00:00:00.200                                  00:00:00.200  00:00:00.200
# 00:00:00.300                                  00:00:00.300  00:00:00.300
# 00:00:00.400                                  00:00:00.400  00:00:00.400
# ...                                                    ...           ...
# 00:00:11.848_Керов Андрей_10  00:00:11.848_Керов Андрей_10  00:00:11.848
# 00:00:11.878_Керов Андрей_10  00:00:11.878_Керов Андрей_10  00:00:11.878
# 00:00:11.909_Керов Андрей_10  00:00:11.909_Керов Андрей_10  00:00:11.909
# 00:00:11.939_Керов Андрей_10  00:00:11.939_Керов Андрей_10  00:00:11.939
# 00:00:11.969_Керов Андрей_10  00:00:11.969_Керов Андрей_10  00:00:11.969
#
#                                Neutral     Happy       Sad     Angry  \
# ...

# %%
save_to_db(db_path, df)

# %%
# Open DB

# %%
import sqlite3
import pandas as pd

# %%
name_db
db_path
connection = sqlite3.connect(db_path)
df_3 = pd.read_sql(f'select * from {name_db}', con=connection)
df_3
# Out:
#                             Index_    Video_Time    Neutral        Happy  \
# 0                     00:00:00.000  00:00:00.000  0.9731213   0.01952708
# 1                     00:00:00.100  00:00:00.100  0.9742892   0.02012928
# 2                     00:00:00.200  00:00:00.200  0.9754572   0.02073147
# 3                     00:00:00.300  00:00:00.300  0.9750276   0.02047997
# 4                     00:00:00.400  00:00:00.400  0.9745417    0.0203943
# ...                            ...           ...        ...          ...
# 4469  00:00:11.848_Керов Андрей_10  00:00:11.848  0.9871483  0.001912866
# 4470  00:00:11.878_Керов Андрей_10  00:00:11.878  0.9873014  0.001948485
# 4471  00:00:11.909_Керов Андрей_10  00:00:11.909  0.9874271  0.001981572
# 4472  00:00:11.939_Керов Андрей_10  00:00:11.939  0.9875517  0.002005567
# 4473  00:00:11.969_Керов Андрей_10  00:00:11.969  0.9876461   0.00200902
#
#               Sad        Angry    Surprised       Scared    Disgusted  \
# ...
