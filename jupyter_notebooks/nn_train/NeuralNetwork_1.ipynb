# %%
import pandas as pd
import os

# %%
project_dir_path = os.environ["NIR_1_sem_magistracy"]
data_dir = 'Data'
data_dir = os.path.join(project_dir_path, data_dir)
data_dir
# Out:
# '/home/ivan/Рабочий стол/Учёба/Git/NIR_1_sem_magistracy/Data'

# %%
csv_file = "Participant 1_Aleksashina_Analysis 1_video_20190607_114857_detailed.csv"
csv_path = os.path.join(data_dir, csv_file)
df = pd.read_csv(csv_path, sep='\t', skiprows = lambda i: i in range(8))

# %%
df
# Out:
#               Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:00.000    0.973121  0.019527  0.000404  0.043879  0.004099   0.000322
# 00:00:00.100    0.974289  0.020129  0.000382  0.042413  0.004014   0.000298
# 00:00:00.200    0.975457  0.020731  0.000361  0.040947  0.003930   0.000273
# 00:00:00.300    0.975028  0.020480  0.000345  0.042622  0.003916   0.000256
# 00:00:00.400    0.974542  0.020394  0.000326  0.044417  0.003831   0.000235
# ...                  ...       ...       ...       ...       ...        ...
# 00:01:50.900    0.969587  0.016939  0.000846  0.051552  0.004851   0.000162
# 00:01:51.000    0.969071  0.017130  0.000856  0.052158  0.004848   0.000168
# 00:01:51.100    0.968842  0.017460  0.000885  0.052096  0.004807   0.000172
# 00:01:51.200    0.968608  0.018322  0.000899  0.052130  0.004756   0.000176
# 00:01:51.300    0.968453  0.019037  0.000889  0.052191  0.004726   0.000178
#
#                 Scared  Disgusted   Valence Arousal  ...  \
# 00:00:00.000  0.001946  -0.024352  0.255187  Female  ...
# 00:00:00.100  0.001820  -0.022284  0.260074  Female  ...
# 00:00:00.200  0.001693  -0.020216  0.264960  Female  ...
# 00:00:00.300  0.001549  -0.022143  0.269347  Female  ...
# 00:00:00.400  0.001438  -0.024022  0.273202  Female  ...
# ...                ...        ...       ...     ...  ...
# 00:01:50.900  0.000609  -0.034614  0.317045  Female  ...
# 00:01:51.000  0.000615  -0.035027  0.316651  Female  ...
# 00:01:51.100  0.000620  -0.034636  0.316144  Female  ...
# 00:01:51.200  0.000617  -0.033808  0.315641  Female  ...
# 00:01:51.300  0.000603  -0.033154  0.315094  Female  ...
#
#              Action Unit 07 - Right - Lid Tightener  \
# 00:00:00.000                                    0.0
# 00:00:00.100                                    0.0
# 00:00:00.200                                    0.0
# 00:00:00.300                                    0.0
# 00:00:00.400                                    0.0
# ...                                             ...
# 00:01:50.900                                    0.0
# 00:01:51.000                                    0.0
# 00:01:51.100                                    0.0
# 00:01:51.200                                    0.0
# 00:01:51.300                                    0.0
#
#              Action Unit 12 - Right - Lip Corner Puller  \
# 00:00:00.000                                   0.017570
# 00:00:00.100                                   0.032680
# 00:00:00.200                                   0.047791
# 00:00:00.300                                   0.060645
# 00:00:00.400                                   0.068510
# ...                                                 ...
# 00:01:50.900                                   0.199020
# 00:01:51.000                                   0.202110
# 00:01:51.100                                   0.196561
# 00:01:51.200                                   0.196161
# 00:01:51.300                                   0.193525
#
#              Action Unit 14 - Right - Dimpler  \
# 00:00:00.000                              0.0
# 00:00:00.100                              0.0
# 00:00:00.200                              0.0
# 00:00:00.300                              0.0
# 00:00:00.400                              0.0
# ...                                       ...
# 00:01:50.900                              0.0
# 00:01:51.000                              0.0
# 00:01:51.100                              0.0
# 00:01:51.200                              0.0
# 00:01:51.300                              0.0
#
#              Action Unit 15 - Right - Lip Corner Depressor  \
# 00:00:00.000                                           0.0
# 00:00:00.100                                           0.0
# 00:00:00.200                                           0.0
# 00:00:00.300                                           0.0
# 00:00:00.400                                           0.0
# ...                                                    ...
# 00:01:50.900                                           0.0
# 00:01:51.000                                           0.0
# 00:01:51.100                                           0.0
# 00:01:51.200                                           0.0
# 00:01:51.300                                           0.0
#
#              Action Unit 20 - Right - Lip Stretcher  \
# 00:00:00.000                                    0.0
# 00:00:00.100                                    0.0
# 00:00:00.200                                    0.0
# 00:00:00.300                                    0.0
# 00:00:00.400                                    0.0
# ...                                             ...
# 00:01:50.900                                    0.0
# 00:01:51.000                                    0.0
# 00:01:51.100                                    0.0
# 00:01:51.200                                    0.0
# 00:01:51.300                                    0.0
#
#               Action Unit 43 - Right - Eyes Closed         Stimulus  \
# 00:00:00.000                           No Stimulus  No Event Marker
# 00:00:00.100                           No Stimulus  No Event Marker
# 00:00:00.200                           No Stimulus  No Event Marker
# 00:00:00.300                           No Stimulus  No Event Marker
# 00:00:00.400                           No Stimulus  No Event Marker
# ...                                            ...              ...
# 00:01:50.900                           No Stimulus  No Event Marker
# 00:01:51.000                           No Stimulus  No Event Marker
# 00:01:51.100                           No Stimulus  No Event Marker
# 00:01:51.200                           No Stimulus  No Event Marker
# 00:01:51.300                           No Stimulus  No Event Marker
#
#               Event Marker Participant Name Analysis Index
# 00:00:00.000       UNKNOWN      Aleksashina     Analysis 1
# 00:00:00.100       UNKNOWN      Aleksashina     Analysis 1
# 00:00:00.200       UNKNOWN      Aleksashina     Analysis 1
# 00:00:00.300       UNKNOWN      Aleksashina     Analysis 1
# 00:00:00.400       UNKNOWN      Aleksashina     Analysis 1
# ...                    ...              ...            ...
# 00:01:50.900       UNKNOWN      Aleksashina     Analysis 1
# 00:01:51.000       UNKNOWN      Aleksashina     Analysis 1
# 00:01:51.100       UNKNOWN      Aleksashina     Analysis 1
# 00:01:51.200       UNKNOWN      Aleksashina     Analysis 1
# 00:01:51.300       UNKNOWN      Aleksashina     Analysis 1
#
# [1114 rows x 74 columns]

# %%
df_first = df.columns[0]
df_first
# Out:
# 'Video Time'

# %%
df.index
# Out:
# Index(['00:00:00.000', '00:00:00.100', '00:00:00.200', '00:00:00.300',
#        '00:00:00.400', '00:00:00.500', '00:00:00.600', '00:00:00.700',
#        '00:00:00.800', '00:00:00.900',
#        ...
#        '00:01:50.400', '00:01:50.500', '00:01:50.600', '00:01:50.700',
#        '00:01:50.800', '00:01:50.900', '00:01:51.000', '00:01:51.100',
#        '00:01:51.200', '00:01:51.300'],
#       dtype='object', length=1114)

# %%
df.columns[1:].insert(-2, 'UNKNOWN')
# Out:
# Index(['Neutral', 'Happy', 'Sad', 'Angry', 'Surprised', 'Scared', 'Disgusted',
#        'Valence', 'Arousal', 'Gender', 'Age', 'Beard', 'Moustache', 'Glasses',
#        'Ethnicity', 'Y - Head Orientation', 'X - Head Orientation',
#        'Z - Head Orientation', 'Landmarks', '3d Landmarks', 'Quality', 'Mouth',
#        'Left Eye', 'Right Eye', 'Left Eyebrow', 'Right Eyebrow', 'Identity',
#        'Action Unit 01 - Inner Brow Raiser',
#        'Action Unit 02 - Outer Brow Raiser', 'Action Unit 04 - Brow Lowerer',
#        'Action Unit 05 - Upper Lid Raiser', 'Action Unit 06 - Cheek Raiser',
#        'Action Unit 07 - Lid Tightener', 'Action Unit 09 - Nose Wrinkler',
#        'Action Unit 10 - Upper Lip Raiser',
#        'Action Unit 12 - Lip Corner Puller', 'Action Unit 14 - Dimpler',
#        'Action Unit 15 - Lip Corner Depressor', 'Action Unit 17 - Chin Raiser',
#        'Action Unit 18 - Lip Pucker', 'Action Unit 20 - Lip Stretcher',
#        'Action Unit 23 - Lip Tightener', 'Action Unit 24 - Lip Pressor',
#        'Action Unit 25 - Lips Part', 'Action Unit 26 - Jaw Drop',
#        'Action Unit 27 - Mouth Stretch', 'Action Unit 43 - Eyes Closed',
#        'Action Unit 01 - Left - Inner Brow Raiser',
#        'Action Unit 02 - Left - Outer Brow Raiser',
#        'Action Unit 04 - Left - Brow Lowerer',
#        'Action Unit 05 - Left - Upper Lid Raiser',
#        'Action Unit 06 - Left - Cheek Raiser',
#        'Action Unit 07 - Left - Lid Tightener',
#        'Action Unit 12 - Left - Lip Corner Puller',
#        'Action Unit 14 - Left - Dimpler',
#        'Action Unit 15 - Left - Lip Corner Depressor',
#        'Action Unit 20 - Left - Lip Stretcher',
#        'Action Unit 43 - Left - Eyes Closed',
#        'Action Unit 01 - Right - Inner Brow Raiser',
#        'Action Unit 02 - Right - Outer Brow Raiser',
#        'Action Unit 04 - Right - Brow Lowerer',
#        'Action Unit 05 - Right - Upper Lid Raiser',
#        'Action Unit 06 - Right - Cheek Raiser',
#        'Action Unit 07 - Right - Lid Tightener',
#        'Action Unit 12 - Right - Lip Corner Puller',
#        'Action Unit 14 - Right - Dimpler',
#        'Action Unit 15 - Right - Lip Corner Depressor',
#        'Action Unit 20 - Right - Lip Stretcher',
#        'Action Unit 43 - Right - Eyes Closed', 'Stimulus', 'Event Marker',
#        'UNKNOWN', 'Participant Name', 'Analysis Index'],
#       dtype='object')

# %%
df_first = df.columns[0]
df.columns = df.columns[1:].insert(-2, 'UNKNOWN')
df.insert(0, df_first, df.index)
df
# Out:
#                 Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:00.000  00:00:00.000  0.973121  0.019527  0.000404  0.043879   0.004099
# 00:00:00.100  00:00:00.100  0.974289  0.020129  0.000382  0.042413   0.004014
# 00:00:00.200  00:00:00.200  0.975457  0.020731  0.000361  0.040947   0.003930
# 00:00:00.300  00:00:00.300  0.975028  0.020480  0.000345  0.042622   0.003916
# 00:00:00.400  00:00:00.400  0.974542  0.020394  0.000326  0.044417   0.003831
# ...                    ...       ...       ...       ...       ...        ...
# 00:01:50.900  00:01:50.900  0.969587  0.016939  0.000846  0.051552   0.004851
# 00:01:51.000  00:01:51.000  0.969071  0.017130  0.000856  0.052158   0.004848
# 00:01:51.100  00:01:51.100  0.968842  0.017460  0.000885  0.052096   0.004807
# 00:01:51.200  00:01:51.200  0.968608  0.018322  0.000899  0.052130   0.004756
# 00:01:51.300  00:01:51.300  0.968453  0.019037  0.000889  0.052191   0.004726
#
#                 Scared  Disgusted   Valence   Arousal  ...  \
# 00:00:00.000  0.000322   0.001946 -0.024352  0.255187  ...
# 00:00:00.100  0.000298   0.001820 -0.022284  0.260074  ...
# 00:00:00.200  0.000273   0.001693 -0.020216  0.264960  ...
# 00:00:00.300  0.000256   0.001549 -0.022143  0.269347  ...
# 00:00:00.400  0.000235   0.001438 -0.024022  0.273202  ...
# ...                ...        ...       ...       ...  ...
# 00:01:50.900  0.000162   0.000609 -0.034614  0.317045  ...
# 00:01:51.000  0.000168   0.000615 -0.035027  0.316651  ...
# 00:01:51.100  0.000172   0.000620 -0.034636  0.316144  ...
# 00:01:51.200  0.000176   0.000617 -0.033808  0.315641  ...
# 00:01:51.300  0.000178   0.000603 -0.033154  0.315094  ...
#
#              Action Unit 12 - Right - Lip Corner Puller  \
# 00:00:00.000                                        0.0
# 00:00:00.100                                        0.0
# 00:00:00.200                                        0.0
# 00:00:00.300                                        0.0
# 00:00:00.400                                        0.0
# ...                                                 ...
# 00:01:50.900                                        0.0
# 00:01:51.000                                        0.0
# 00:01:51.100                                        0.0
# 00:01:51.200                                        0.0
# 00:01:51.300                                        0.0
#
#              Action Unit 14 - Right - Dimpler  \
# 00:00:00.000                         0.017570
# 00:00:00.100                         0.032680
# 00:00:00.200                         0.047791
# 00:00:00.300                         0.060645
# 00:00:00.400                         0.068510
# ...                                       ...
# 00:01:50.900                         0.199020
# 00:01:51.000                         0.202110
# 00:01:51.100                         0.196561
# 00:01:51.200                         0.196161
# 00:01:51.300                         0.193525
#
#              Action Unit 15 - Right - Lip Corner Depressor  \
# 00:00:00.000                                           0.0
# 00:00:00.100                                           0.0
# 00:00:00.200                                           0.0
# 00:00:00.300                                           0.0
# 00:00:00.400                                           0.0
# ...                                                    ...
# 00:01:50.900                                           0.0
# 00:01:51.000                                           0.0
# 00:01:51.100                                           0.0
# 00:01:51.200                                           0.0
# 00:01:51.300                                           0.0
#
#              Action Unit 20 - Right - Lip Stretcher  \
# 00:00:00.000                                    0.0
# 00:00:00.100                                    0.0
# 00:00:00.200                                    0.0
# 00:00:00.300                                    0.0
# 00:00:00.400                                    0.0
# ...                                             ...
# 00:01:50.900                                    0.0
# 00:01:51.000                                    0.0
# 00:01:51.100                                    0.0
# 00:01:51.200                                    0.0
# 00:01:51.300                                    0.0
#
#              Action Unit 43 - Right - Eyes Closed     Stimulus  \
# 00:00:00.000                                  0.0  No Stimulus
# 00:00:00.100                                  0.0  No Stimulus
# 00:00:00.200                                  0.0  No Stimulus
# 00:00:00.300                                  0.0  No Stimulus
# 00:00:00.400                                  0.0  No Stimulus
# ...                                           ...          ...
# 00:01:50.900                                  0.0  No Stimulus
# 00:01:51.000                                  0.0  No Stimulus
# 00:01:51.100                                  0.0  No Stimulus
# 00:01:51.200                                  0.0  No Stimulus
# 00:01:51.300                                  0.0  No Stimulus
#
#                  Event Marker  UNKNOWN  Participant Name Analysis Index
# 00:00:00.000  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:00:00.100  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:00:00.200  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:00:00.300  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:00:00.400  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# ...                       ...      ...               ...            ...
# 00:01:50.900  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:01:51.000  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:01:51.100  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:01:51.200  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:01:51.300  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
#
# [1114 rows x 75 columns]

# %%
seven_vector = df[
    [
        'Neutral', 
        'Happy', 
        'Sad', 
        'Angry', 
        'Surprised', 
        'Scared', 
        'Disgusted'
    ]
]

# %%
seven_vector
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00:00.000  0.973121  0.019527  0.000404  0.043879   0.004099  0.000322
# 00:00:00.100  0.974289  0.020129  0.000382  0.042413   0.004014  0.000298
# 00:00:00.200  0.975457  0.020731  0.000361  0.040947   0.003930  0.000273
# 00:00:00.300  0.975028  0.020480  0.000345  0.042622   0.003916  0.000256
# 00:00:00.400  0.974542  0.020394  0.000326  0.044417   0.003831  0.000235
# ...                ...       ...       ...       ...        ...       ...
# 00:01:50.900  0.969587  0.016939  0.000846  0.051552   0.004851  0.000162
# 00:01:51.000  0.969071  0.017130  0.000856  0.052158   0.004848  0.000168
# 00:01:51.100  0.968842  0.017460  0.000885  0.052096   0.004807  0.000172
# 00:01:51.200  0.968608  0.018322  0.000899  0.052130   0.004756  0.000176
# 00:01:51.300  0.968453  0.019037  0.000889  0.052191   0.004726  0.000178
#
#               Disgusted
# 00:00:00.000   0.001946
# 00:00:00.100   0.001820
# 00:00:00.200   0.001693
# 00:00:00.300   0.001549
# 00:00:00.400   0.001438
# ...                 ...
# 00:01:50.900   0.000609
# 00:01:51.000   0.000615
# 00:01:51.100   0.000620
# 00:01:51.200   0.000617
# 00:01:51.300   0.000603
#
# [1114 rows x 7 columns]

# %%
pa_vector = df[
    [
        'Valence',
        'Arousal'
    ]
]

# %%
pa_vector
# Out:
#                Valence   Arousal
# 00:00:00.000 -0.024352  0.255187
# 00:00:00.100 -0.022284  0.260074
# 00:00:00.200 -0.020216  0.264960
# 00:00:00.300 -0.022143  0.269347
# 00:00:00.400 -0.024022  0.273202
# ...                ...       ...
# 00:01:50.900 -0.034614  0.317045
# 00:01:51.000 -0.035027  0.316651
# 00:01:51.100 -0.034636  0.316144
# 00:01:51.200 -0.033808  0.315641
# 00:01:51.300 -0.033154  0.315094
#
# [1114 rows x 2 columns]

# %%
# n = 152
# print(reader[n].split('\t')[23] + ' ' + reader[n].split('\t')[24])
# # print(reader[n].split('\t')[36])
# # print(reader[n].split('\t')[70])
# print('Valence', reader[n].split('\t')[8])
# print('Arousal', reader[n].split('\t')[9])
# print(reader[n].split('\t')[0])

# %%
# n = 659
# print(reader[n].split('\t')[23] + ' ' + reader[n].split('\t')[24])
# # print(reader[n].split('\t')[36])
# # print(reader[n].split('\t')[70])
# print('Valence', reader[n].split('\t')[8])
# print('Arousal', reader[n].split('\t')[9])
# print(reader[n].split('\t')[0])

# %%
# class

# %%
# def emotion_at_timestamp(reader, timestamp):
#

# %%
len(pa_vector)
# Out:
# 1114

# %%
pa_vector['Valence'][1]
# Out:
# -0.02228404

# %%
# x = [list(pa_vector['Valence']), list(pa_vector['Arousal'])]
x = []
for i in range(len(pa_vector)):
    x.append((pa_vector['Valence'][i], pa_vector['Arousal'][i]))

# %%
x[0]
# Out:
# (-0.0243521, 0.2551869)

# %%
x[1]
# Out:
# (-0.02228404, 0.2600735)

# %%
import numpy as np

# %%
x = np.array(x)

# %%
x.shape
# Out:
# (1114, 2)

# %%
print(len(x[0]) == len(x[1])) # Теряет смысл (для старого было актуально)
print(len(x[0]))
# Out:
# True
# 2

# %%
# y = [list(seven_vector[col]) for col in seven_vector.columns]
y = []
for i in range(len(pa_vector)):
    y.append(tuple(seven_vector[col][i] for col in seven_vector.columns))

# %%
y[0]
# Out:
# (0.9731213,
#  0.01952708,
#  0.000403907,
#  0.04387918,
#  0.004098584,
#  0.000322345,
#  0.001946207)

# %%
y = np.array(y)

# %%
y.shape
# Out:
# (1114, 7)

# %%
print(len(y[0]) == len(y[6]))
print(len(y[0]))
# Out:
# True
# 7

# %%
from keras.models import Model
from keras.layers import Input, Dense

# %%
a = Input(shape=(2,))
b = Dense(7)(a)
model = Model(inputs=a, outputs=b)
model.compile(optimizer='adam', loss='mse')

# %%
print(a)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 2), dtype=tf.float32, name='input_3'), name='input_3', description="created by layer 'input_3'")

# %%
x[0]
# Out:
# array([-0.0243521,  0.2551869])

# %%
model.fit(x=x, y=y, epochs=20)
# Out:
# Epoch 1/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1757
# Epoch 2/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1501
# Epoch 3/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1290
# Epoch 4/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1115
# Epoch 5/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0970
# Epoch 6/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0849
# Epoch 7/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0749
# Epoch 8/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0665
# Epoch 9/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0595
# Epoch 10/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0536
# Epoch 11/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0486
# Epoch 12/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0443
# Epoch 13/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0406
# Epoch 14/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0375
# Epoch 15/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0348
# Epoch 16/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0324
# Epoch 17/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0304
# Epoch 18/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0286
# Epoch 19/20
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 20/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0257

# %%
# ! pip install pydot
# ! sudo apt-get install graphviz graphviz-dev
# ! pip install pygraphviz
# Out:
# Requirement already satisfied: pydot in /home/ivan/Рабочий стол/Учёба/Git/NIR_1_sem_magistracy/venv/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/ivan/Рабочий стол/Учёба/Git/NIR_1_sem_magistracy/venv/lib/python3.9/site-packages (from pydot) (3.0.7)
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the '/home/ivan/Рабочий стол/Учёба/Git/NIR_1_sem_magistracy/venv/bin/python -m pip install --upgrade pip' command.
# Collecting pygraphviz
#   Using cached pygraphviz-1.11.zip (120 kB)
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.11-cp39-cp39-linux_x86_64.whl size=230354 sha256=cf20eec98fa6e7a78a86798c97923e47eb128ad5cc8134c22cf26f59439140dc
#   Stored in directory: /home/ivan/.cache/pip/wheels/2a/15/84/0cfa4492795c389d89e0c3101f6d42e6201a66869a9c8b576e
# Successfully built pygraphviz
# Installing collected packages: pygraphviz
# Successfully installed pygraphviz-1.11
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the '/home/ivan/Рабочий стол/Учёба/Git/NIR_1_sem_magistracy/venv/bin/python -m pip install --upgrade pip' command.

# %%
from tensorflow.keras.utils import plot_model

# %%
architecture_models_dir = 'architecture_models'
path = os.path.join(project_dir_path, architecture_models_dir, '1.png')
plot_model(model, to_file=path, show_shapes=True, show_layer_names=True)

# %%
def get_df_xy(from_, to, xy = None):
    if xy is None:
        xy = 'x'
    if xy.lower() == 'x':   
        df_x = pd.DataFrame(x[from_:to])
        df_x.columns = pa_vector.columns
        return df_x
    elif xy.lower() == 'y':   
        df_y = pd.DataFrame(y[from_:to])
        df_y.columns = seven_vector.columns
        return df_y

# %%
df_x = pd.DataFrame(x[:2])
df_x.columns = pa_vector.columns
df_x
# Out:
#     Valence   Arousal
# 0 -0.024352  0.255187
# 1 -0.022284  0.260074

# %%
df_x.values
# Out:
# array([[-0.0243521 ,  0.2551869 ],
#        [-0.02228404,  0.2600735 ]])

# %%
get_df_xy(1, 5)
# Out:
#     Valence   Arousal
# 0 -0.022284  0.260074
# 1 -0.020216  0.264960
# 2 -0.022143  0.269347
# 3 -0.024022  0.273202

# %%
df_y = pd.DataFrame(y[:2])
df_y.columns = seven_vector.columns
df_y
# Out:
#     Neutral     Happy       Sad     Angry  Surprised    Scared  Disgusted
# 0  0.973121  0.019527  0.000404  0.043879   0.004099  0.000322   0.001946
# 1  0.974289  0.020129  0.000382  0.042413   0.004014  0.000298   0.001820

# %%
get_df_xy(0, 2, 'Y')
# Out:
#     Neutral     Happy       Sad     Angry  Surprised    Scared  Disgusted
# 0  0.973121  0.019527  0.000404  0.043879   0.004099  0.000322   0.001946
# 1  0.974289  0.020129  0.000382  0.042413   0.004014  0.000298   0.001820

# %%
pd.DataFrame(model.predict(df_x.values))
# Out:
#           0         1         2         3         4         5         6
# 0  0.547031  0.146414 -0.053892  0.173786  0.089274 -0.053322  0.008163
# 1  0.547913  0.149612 -0.054384  0.175373  0.087503 -0.053296  0.010840

# %%
def predict(df_x):
    df_res = pd.DataFrame(model.predict(df_x.values))
    df_res.columns = seven_vector.columns
    return df_res

# %%
predict(df_x)
# Out:
#     Neutral     Happy       Sad     Angry  Surprised    Scared  Disgusted
# 0  0.547031  0.146414 -0.053892  0.173786   0.089274 -0.053322   0.008163
# 1  0.547913  0.149612 -0.054384  0.175373   0.087503 -0.053296   0.010840

# %%
df[:2]
# Out:
#                 Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:00.000  00:00:00.000  0.973121  0.019527  0.000404  0.043879   0.004099
# 00:00:00.100  00:00:00.100  0.974289  0.020129  0.000382  0.042413   0.004014
#
#                 Scared  Disgusted   Valence   Arousal  ...  \
# 00:00:00.000  0.000322   0.001946 -0.024352  0.255187  ...
# 00:00:00.100  0.000298   0.001820 -0.022284  0.260074  ...
#
#              Action Unit 12 - Right - Lip Corner Puller  \
# 00:00:00.000                                        0.0
# 00:00:00.100                                        0.0
#
#              Action Unit 14 - Right - Dimpler  \
# 00:00:00.000                          0.01757
# 00:00:00.100                          0.03268
#
#              Action Unit 15 - Right - Lip Corner Depressor  \
# 00:00:00.000                                           0.0
# 00:00:00.100                                           0.0
#
#              Action Unit 20 - Right - Lip Stretcher  \
# 00:00:00.000                                    0.0
# 00:00:00.100                                    0.0
#
#              Action Unit 43 - Right - Eyes Closed     Stimulus  \
# 00:00:00.000                                  0.0  No Stimulus
# 00:00:00.100                                  0.0  No Stimulus
#
#                  Event Marker  UNKNOWN  Participant Name Analysis Index
# 00:00:00.000  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
# 00:00:00.100  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
#
# [2 rows x 75 columns]

# %%
from_ = 100
to = 102

df_x = get_df_xy(from_, to)
df_x
# Out:
#     Valence   Arousal
# 0 -0.012470  0.312041
# 1 -0.008536  0.311438

# %%
df_y = get_df_xy(from_, to, 'y')
df_y
# Out:
#     Neutral     Happy       Sad     Angry  Surprised    Scared  Disgusted
# 0  0.975340  0.028737  0.000504  0.041206   0.005349  0.000403   0.000438
# 1  0.975774  0.030997  0.000505  0.039533   0.005380  0.000415   0.000436

# %%
predict(df_x)
# Out:
#     Neutral     Happy       Sad     Angry  Surprised    Scared  Disgusted
# 0  0.561536  0.175793 -0.063081  0.197231   0.070867 -0.055822   0.042799
# 1  0.559968  0.178093 -0.061829  0.195321   0.070332 -0.054863   0.041265

# %%
class NeuralNetwork:
    def __init__(self, x, y, model):
        self.df_x = x
        self.df_y = y
        self.model = model
        self.from_ = 0
        self.to = 1
    
    def get_df_xy(self, from_ = None, to = None, xy = None):
        if xy is None:
            xy = 'x'
        
        if from_ is None:
            from_ = self.from_
        else:
            self.from_ = from_
            
        if to is None:
            to = self.to
        else:
            self.to = to
        
        if xy.lower() == 'x':   
            return self.df_x[from_:to]
        elif xy.lower() == 'y':   
            return self.df_y[from_:to]
    
    def predict(self):
        df_x = self.get_df_xy(self.from_, self.to)
        df_res = pd.DataFrame(self.model.predict(df_x.values))
        df_res.columns = self.df_y.columns
        df_res.index = df_x.index
        return df_res

# %%
model

# %%
nn = NeuralNetwork(pa_vector, seven_vector, model)

# %%
df_x = nn.get_df_xy('00:00:00.000', '00:00:00.100')
df_x
# Out:
#                Valence   Arousal
# 00:00:00.000 -0.024352  0.255187
# 00:00:00.100 -0.022284  0.260074

# %%
pa_vector[0:1]
# Out:
#                Valence   Arousal
# 00:00:00.000 -0.024352  0.255187

# %%
df_y = nn.get_df_xy(xy = 'y')
df_y
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00:00.000  0.973121  0.019527  0.000404  0.043879   0.004099  0.000322
# 00:00:00.100  0.974289  0.020129  0.000382  0.042413   0.004014  0.000298
#
#               Disgusted
# 00:00:00.000   0.001946
# 00:00:00.100   0.001820

# %%
nn.predict() # Not neutral
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00:00.000  0.547031  0.146414 -0.053892  0.173786   0.089274 -0.053322
# 00:00:00.100  0.547913  0.149612 -0.054384  0.175373   0.087503 -0.053296
#
#               Disgusted
# 00:00:00.000   0.008163
# 00:00:00.100   0.010840

# %%
df_x = nn.get_df_xy('00:00:16.000', '00:00:17.000') # Happy
df_x
# Out:
#                Valence   Arousal
# 00:00:16.000  0.982274  0.763761
# 00:00:16.100  0.982497  0.761543
# 00:00:16.200  0.982457  0.759395
# 00:00:16.300  0.982780  0.757186
# 00:00:16.400  0.983181  0.754926
# 00:00:16.500  0.983513  0.752694
# 00:00:16.600  0.983897  0.750396
# 00:00:16.700  0.983741  0.748033
# 00:00:16.800  0.982967  0.745634
# 00:00:16.900  0.982504  0.743361
# 00:00:17.000  0.982369  0.741136

# %%
nn.from_
# Out:
# '00:00:16.000'

# %%
nn.to
# Out:
# '00:00:17.000'

# %%
df_y = nn.get_df_xy(xy = 'y')
df_y
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00:16.000  0.007980  0.984054  0.000013  0.001780   0.002200  0.001339
# 00:00:16.100  0.007884  0.984246  0.000013  0.001749   0.002323  0.001302
# 00:00:16.200  0.007840  0.984331  0.000013  0.001875   0.002367  0.001226
# 00:00:16.300  0.007679  0.984653  0.000014  0.001873   0.002433  0.001246
# 00:00:16.400  0.007520  0.984970  0.000014  0.001789   0.002598  0.001347
# 00:00:16.500  0.007385  0.985240  0.000014  0.001727   0.002701  0.001379
# 00:00:16.600  0.007240  0.985530  0.000014  0.001633   0.002647  0.001379
# 00:00:16.700  0.007345  0.985320  0.000014  0.001580   0.002596  0.001452
# 00:00:16.800  0.007730  0.984552  0.000013  0.001585   0.002543  0.001457
# 00:00:16.900  0.007821  0.984368  0.000013  0.001865   0.002409  0.001359
# 00:00:17.000  0.007792  0.984427  0.000013  0.002058   0.002319  0.001242
#
#               Disgusted
# 00:00:16.000   0.000060
# 00:00:16.100   0.000059
# 00:00:16.200   0.000057
# 00:00:16.300   0.000056
# 00:00:16.400   0.000054
# 00:00:16.500   0.000054
# 00:00:16.600   0.000053
# 00:00:16.700   0.000057
# 00:00:16.800   0.000060
# 00:00:16.900   0.000064
# 00:00:17.000   0.000064

# %%
nn.predict() # Neutral, but shouldn't be
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00:16.000  0.363186  0.988454  0.119915  0.015015  -0.237294  0.131117
# 00:00:16.100  0.362381  0.987750  0.120468  0.013819  -0.236699  0.131372
# 00:00:16.200  0.361691  0.986902  0.120932  0.012766  -0.236077  0.131560
# 00:00:16.300  0.360854  0.986266  0.121512  0.011534  -0.235503  0.131838
# 00:00:16.400  0.359973  0.985660  0.122125  0.010244  -0.234928  0.132137
# 00:00:16.500  0.359125  0.985020  0.122713  0.008997  -0.234349  0.132419
# 00:00:16.600  0.358238  0.984389  0.123330  0.007695  -0.233761  0.132719
# 00:00:16.700  0.357518  0.983385  0.123808  0.006583  -0.233056  0.132900
# 00:00:16.800  0.357001  0.981971  0.124118  0.005705  -0.232231  0.132943
# 00:00:16.900  0.356417  0.980803  0.124489  0.004763  -0.231497  0.133046
# 00:00:17.000  0.355734  0.979866  0.124943  0.003710  -0.230836  0.133219
#
#               Disgusted
# 00:00:16.000   0.059298
# 00:00:16.100   0.057750
# 00:00:16.200   0.056324
# 00:00:16.300   0.054753
# 00:00:16.400   0.053125
# 00:00:16.500   0.051535
# 00:00:16.600   0.049887
# 00:00:16.700   0.048351
# 00:00:16.800   0.046968
# 00:00:16.900   0.045580
# 00:00:17.000   0.044129

# %%
df[df['Video Time'] == '00:00:16.100']
# Out:
#                 Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:16.100  00:00:16.100  0.007884  0.984246  0.000013  0.001749   0.002323
#
#                 Scared  Disgusted   Valence   Arousal  ...  \
# 00:00:16.100  0.001302   0.000059  0.982497  0.761543  ...
#
#              Action Unit 12 - Right - Lip Corner Puller  \
# 00:00:16.100                                   0.833863
#
#              Action Unit 14 - Right - Dimpler  \
# 00:00:16.100                              0.0
#
#              Action Unit 15 - Right - Lip Corner Depressor  \
# 00:00:16.100                                           0.0
#
#              Action Unit 20 - Right - Lip Stretcher  \
# 00:00:16.100                                    0.0
#
#              Action Unit 43 - Right - Eyes Closed     Stimulus  \
# 00:00:16.100                                  0.0  No Stimulus
#
#                  Event Marker  UNKNOWN  Participant Name Analysis Index
# 00:00:16.100  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
#
# [1 rows x 75 columns]

# %%
df[df.index == '00:00:16.100']
# Out:
#                 Video Time   Neutral     Happy       Sad     Angry  Surprised  \
# 00:00:16.100  00:00:16.100  0.007884  0.984246  0.000013  0.001749   0.002323
#
#                 Scared  Disgusted   Valence   Arousal  ...  \
# 00:00:16.100  0.001302   0.000059  0.982497  0.761543  ...
#
#              Action Unit 12 - Right - Lip Corner Puller  \
# 00:00:16.100                                   0.833863
#
#              Action Unit 14 - Right - Dimpler  \
# 00:00:16.100                              0.0
#
#              Action Unit 15 - Right - Lip Corner Depressor  \
# 00:00:16.100                                           0.0
#
#              Action Unit 20 - Right - Lip Stretcher  \
# 00:00:16.100                                    0.0
#
#              Action Unit 43 - Right - Eyes Closed     Stimulus  \
# 00:00:16.100                                  0.0  No Stimulus
#
#                  Event Marker  UNKNOWN  Participant Name Analysis Index
# 00:00:16.100  No Event Marker  UNKNOWN       Aleksashina     Analysis 1
#
# [1 rows x 75 columns]

# %%
df_x = nn.get_df_xy('00:00:21.000', '00:00:23.000') # Serious
df_x
# Out:
#                Valence   Arousal
# 00:00:21.000  0.964579  0.663201
# 00:00:21.100  0.943782  0.659207
# 00:00:21.200  0.871111  0.652940
# 00:00:21.300  0.762326  0.644623
# 00:00:21.400  0.640243  0.633058
# 00:00:21.500  0.520727  0.618742
# 00:00:21.600  0.413288  0.603645
# 00:00:21.700  0.323662  0.588063
# 00:00:21.800  0.251679  0.572172
# 00:00:21.900  0.194049  0.555099
# 00:00:22.000  0.148148  0.536985
# 00:00:22.100  0.111093  0.518199
# 00:00:22.200  0.080803  0.499630
# 00:00:22.300  0.054733  0.481918
# 00:00:22.400  0.034692  0.465653
# 00:00:22.500  0.019820  0.451096
# 00:00:22.600  0.007910  0.438177
# 00:00:22.700 -0.006161  0.426671
# 00:00:22.800 -0.020030  0.416402
# 00:00:22.900 -0.035617  0.407217
# 00:00:23.000 -0.047857  0.399033

# %%
df_y = nn.get_df_xy(xy = 'y') # Serious
df_y
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00
# 00:00:36.800  0.218805  0.557725  0.000121  0.583918   0.000159  0.000102
# 00:00:36.900  0.219156  0.565864  0.000115  0.577523   0.000164  0.000101
# 00:00:37.000  0.220346  0.569772  0.000110  0.568527   0.000171  0.000101
#
#               Disgusted
# 00:00:36.000   0.000912
# 00:00:36.100   0.000907
# 00:00:36.200   0.000883
# 00:00:36.300   0.000835
# 00:00:36.400   0.000784
# 00:00:36.500   0.000746
# 00:00:36.600   0.000718
# 00:00:36.700   0.000705
# 00:00:36.800   0.000706
# 00:00:36.900   0.000695
# 00:00:37.000   0.000689

# %%
nn.predict() # Отвратно! (Angry столбец, Happy!!!)
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00:36.000  0.615062  0.025963 -0.109184  0.254322   0.121997 -0.097530
# 00:00:36.100  0.615044  0.025359 -0.109199  0.254228   0.122281 -0.097598
# 00:00:36.200  0.603834  0.045484 -0.100075  0.240990   0.116761 -0.090279
# 00:00:36.300  0.591038  0.068833 -0.089642  0.225920   0.110287 -0.081876
# 00:00:36.400  0.580802  0.087681 -0.081289  0.213885   0.105029 -0.075134
# 00:00:36.500  0.571473  0.104911 -0.073673  0.202923   0.100213 -0.068982
# 00:00:36.600  0.564212  0.121486 -0.067596  0.194751   0.095006 -0.063796
# 00:00:36.700  0.555845  0.140090 -0.060617  0.185277   0.089235 -0.057882
# 00:00:36.800  0.551646  0.149862 -0.057094  0.180573   0.086137 -0.054859
# 00:00:36.900  0.547247  0.159986 -0.053409  0.175632   0.082944 -0.051707
# 00:00:37.000  0.543299  0.168924 -0.050108  0.171179   0.080147 -0.048896
#
#               Disgusted
# 00:00:36.000   0.066386
# 00:00:36.100   0.066114
# 00:00:36.200   0.056632
# 00:00:36.300   0.045960
# 00:00:36.400   0.037492
# 00:00:36.500   0.029797
# 00:00:36.600   0.025083
# 00:00:36.700   0.019452
# 00:00:36.800   0.016802
# 00:00:36.900   0.013981
# 00:00:37.000   0.011387

# %%
df_x = nn.get_df_xy('00:00:47.000', '00:00:48.000') # Удивление (Neutral + Happy)
df_x
# Out:
#                Valence   Arousal
# 00:00:47.000  0.402050  0.299550
# 00:00:47.100  0.402333  0.299550
# 00:00:47.200  0.403500  0.299481
# 00:00:47.300  0.406274  0.299384
# 00:00:47.400  0.406193  0.299230
# 00:00:47.500  0.415290  0.299125
# 00:00:47.600  0.418139  0.298942
# 00:00:47.700  0.423579  0.298760
# 00:00:47.800  0.431206  0.298555
# 00:00:47.900  0.440355  0.298336
# 00:00:48.000  0.450727  0.298102

# %%
df_y = nn.get_df_xy(xy = 'y')
df_y
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:00:47.000  0.710237  0.407821  0.000096  0.005771   0.004438  0.000165
# 00:00:47.100  0.711148  0.408063  0.000100  0.005730   0.004281  0.000168
# 00:00:47.200  0.713677  0.409234  0.000102  0.005734   0.004085  0.000167
# 00:00:47.300  0.714254  0.412195  0.000105  0.005921   0.003882  0.000161
# 00:00:47.400  0.716460  0.412444  0.000108  0.006251   0.003699  0.000162
# 00:00:47.500  0.713320  0.421777  0.000107  0.006487   0.003612  0.000162
df_y
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:01:06.000  0.735105  0.152540  0.000869  0.255649   0.001597  0.000651
# 00:01:06.100  0.734141  0.157158  0.000902  0.249441   0.001582  0.000660
# 00:01:06.200  0.734078  0.159937  0.000916  0.245525   0.001590  0.000643
# 00:01:06.300  0.734819  0.161817  0.000917  0.243539   0.001637  0.000628
# 00:01:06.400  0.744191  0.165657  0.000897  0.236280   0.001662  0.000610
# 00:01:06.500  0.753816  0.168743  0.000880  0.227929   0.001680  0.000600
# 00:01:06.600  0.764034  0.169269  0.000862  0.218453   0.001695  0.000586
# 00:01:06.700  0.775219  0.172246  0.000826  0.207403   0.001711  0.000575
# 00:01:06.800  0.785698  0.174468  0.000797  0.197109   0.001756  0.000571
# 00:01:06.900  0.793438  0.177854  0.000771  0.186146   0.001756  0.000576
# 00:01:07.000  0.796028  0.178233  0.000745  0.180022   0.001700  0.000569
#
#               Disgusted
# 00:01:06.000   0.000894
# 00:01:06.100   0.000887
# 00:01:06.200   0.000889
# 00:01:06.300   0.000900
# 00:01:06.400   0.000898
# 00:01:06.500   0.000896
# 00:01:06.600   0.000879
# 00:01:06.700   0.000872
# 00:01:06.800   0.000872
# 00:01:06.900   0.000882
# 00:01:07.000   0.000939

# %%
nn.predict() # Neutral - не очень!
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:01:06.000  0.583636  0.106439 -0.082470  0.219950   0.095431 -0.073985
# 00:01:06.100  0.579805  0.113333 -0.079351  0.215427   0.093537 -0.071481
# 00:01:06.200  0.577382  0.117536 -0.077386  0.212549   0.092412 -0.069918
# 00:01:06.300  0.575924  0.119892 -0.076211  0.210797   0.091814 -0.068998
# 00:01:06.400  0.571898  0.126846 -0.072947  0.206011   0.089958 -0.066404
# 00:01:06.500  0.567739  0.134000 -0.069577  0.201063   0.088055 -0.063728
# 00:01:06.600  0.564067  0.140215 -0.066606  0.196684   0.086421 -0.061378
# 00:01:06.700  0.558989  0.149015 -0.062488  0.190651   0.084066 -0.058102
# 00:01:06.800  0.554435  0.156840 -0.058798  0.185233   0.081985 -0.055173
# 00:01:06.900  0.549231  0.165831 -0.054579  0.179046   0.079584 -0.051819
# 00:01:07.000  0.546803  0.169826 -0.052620  0.176138   0.078556 -0.050280
#
#               Disgusted
# 00:01:06.000   0.049514
# 00:01:06.100   0.046280
# 00:01:06.200   0.044172
# 00:01:06.300   0.042832
# 00:01:06.400   0.039317
# 00:01:06.500   0.035672
# 00:01:06.600   0.032414
# 00:01:06.700   0.027992
# 00:01:06.800   0.023999
# 00:01:06.900   0.019454
# 00:01:07.000   0.017255

# %%
df_x = nn.get_df_xy('00:01:25.000', '00:01:26.000') # Happy (little)
df_x
# Out:
#                Valence   Arousal
# 00:01:25.000  0.780514  0.429943
# 00:01:25.100  0.770180  0.429943
# 00:01:25.200  0.763402  0.429846
# 00:01:25.300  0.759536  0.429766
# 00:01:25.400  0.746653  0.429272
# 00:01:25.500  0.735193  0.428437
# 00:01:25.600  0.723706  0.427788
# 00:01:25.700  0.711666  0.427098
# 00:01:25.800  0.700324  0.426254
# 00:01:25.900  0.687633  0.425157
# 00:01:26.000  0.678700  0.423820

# %%
df_y = nn.get_df_xy(xy = 'y')
df_y
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:01:38.000  0.247921  0.727225  0.000302  0.002924   0.002745  0.003063
# 00:01:38.100  0.245379  0.728168  0.000297  0.002864   0.002651  0.002912
# 00:01:38.200  0.248069  0.728863  0.000286  0.002826   0.002657  0.002941
# 00:01:38.300  0.249211  0.735282  0.000272  0.002743   0.002670  0.002996
# 00:01:38.400  0.262386  0.731932  0.000260  0.002584   0.002722  0.002937
# 00:01:38.500  0.279061  0.725456  0.000248  0.002368   0.002732  0.002796
# 00:01:38.600  0.286941  0.721679  0.000234  0.002201   0.002678  0.002692
# 00:01:38.700  0.286773  0.721287  0.000228  0.002108   0.002710  0.002639
# 00:01:38.800  0.286524  0.719876  0.000228  0.002073   0.002824  0.002564
# 00:01:38.900  0.286901  0.718372  0.000235  0.002071   0.002820  0.002526
# 00:01:39.000  0.282643  0.719507  0.000245  0.002121   0.002750  0.002556
#
#               Disgusted
# 00:01:38.000   0.000617
# 00:01:38.100   0.000596
# 00:01:38.200   0.000590
# 00:01:38.300   0.000580
# 00:01:38.400   0.000555
# 00:01:38.500   0.000528
# 00:01:38.600   0.000514
# 00:01:38.700   0.000534
# 00:01:38.800   0.000535
# 00:01:38.900   0.000525
# 00:01:39.000   0.000521

# %%
nn.predict() # Норм!
# Out:
#                Neutral     Happy       Sad     Angry  Surprised    Scared  \
# 00:01:38.000  0.332764  0.682122  0.127634 -0.062050  -0.085866  0.105578
# 00:01:38.100  0.332111  0.682509  0.128128 -0.062911  -0.085826  0.105906
# 00:01:38.200  0.331604  0.682617  0.128503 -0.063601  -0.085706  0.106136
# 00:01:38.300  0.329093  0.686368  0.130511 -0.066652  -0.086593  0.107680
# 00:01:38.400  0.329887  0.683840  0.129812 -0.065840  -0.085694  0.107023
# 00:01:38.500  0.331660  0.679259  0.128303 -0.063906  -0.084176  0.105690
# 00:01:38.600  0.332513  0.676399  0.127547 -0.063050  -0.083144  0.104966
# 00:01:38.700  0.332248  0.675735  0.127708 -0.063493  -0.082749  0.104995
# 00:01:38.800  0.332329  0.674427  0.127588 -0.063530  -0.082173  0.104797
# 00:01:38.900  0.332431  0.673007  0.127446 -0.063550  -0.081553  0.104574
# 00:01:39.000  0.331656  0.673263  0.128023 -0.064595  -0.081411  0.104937
#
#               Disgusted
# 00:01:38.000  -0.112113
# 00:01:38.100  -0.112982
# 00:01:38.200  -0.113735
# 00:01:38.300  -0.116164
# 00:01:38.400  -0.115937
# 00:01:38.500  -0.115002
# 00:01:38.600  -0.114817
# 00:01:38.700  -0.115501
# 00:01:38.800  -0.115902
# 00:01:38.900  -0.116314
# 00:01:39.000  -0.117428

# %%
a = Input(shape=(2,))
first = Dense(4)(a)
b = Dense(7)(first)
model = Model(inputs=a, outputs=b)
model.compile(optimizer='adam', loss='mse')
model.fit(x=x, y=y, epochs=20)
# Out:
# Epoch 1/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1981
# Epoch 2/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1415
# Epoch 3/20
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1086
# Epoch 4/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0874
# Epoch 5/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0725
# Epoch 6/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0611
# Epoch 7/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0519
# Epoch 8/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0442
# Epoch 9/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0378
# Epoch 10/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0326
# Epoch 11/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 12/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 13/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0221
# Epoch 14/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0201
# Epoch 15/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 16/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 17/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 18/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0164
# Epoch 19/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0160
# Epoch 20/20
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0158
